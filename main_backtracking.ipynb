# %% [markdown]
# ## Backtracking
#
# Busca em profundidade com limite `p`. Em cada nó escolhe a próxima regra ainda não tentada, em ordem crescente (`"asc"`, padrão) ou decrescente (`"desc"`). Se chegar ao limite, se `R(N)` ficar vazio, ou se o estado já estiver no caminho S–N, recua ao pai e tenta a próxima regra.
#
# A célula abaixo imprime só o **caminho que deu certo**: em cada passo, as regras possíveis naquele estado, os recuos daquele nó e a regra aplicada.
#
# Código: `algorithms/backtracking.py`

# %%
import sys
from pathlib import Path
import importlib

sys.path.insert(0, str(Path("algorithms").resolve()))

import backtracking as bt
from utils import INITIAL_STATE

importlib.reload(bt)

P     = 36     # limite de profundidade (inteiro positivo)
ORDER = "asc"  # "asc"  → r1, r2, …, r16  |  "desc" → r16, r15, …, r1

result = bt.backtracking(INITIAL_STATE, depth_limit=P, order=ORDER)
if result is None:
    print(f"Fracasso: nenhuma solução encontrada com p = {P}, order = {ORDER!r}.")
else:
    path, applied, tried = result
    print(f"Sucesso! Solução com {len(applied)} movimentos (p = {P}, order = {ORDER!r}):")
    print(" -> ".join(applied))
    bt.print_solution(path, applied, tried)
# Out:
# Sucesso! Solução com 36 movimentos (p = 36, order = 'asc'):
# r1 -> r5 -> r9 -> r2 -> r7 -> r11 -> r5 -> r13 -> r1 -> r7 -> r6 -> r3 -> r9 -> r11 -> r14 -> r16 -> r1 -> r3 -> r6 -> r7 -> r9 -> r5 -> r11 -> r1 -> r4 -> r7 -> r10 -> r11 -> r13 -> r1 -> r6 -> r10 -> r13 -> r16 -> r4 -> r7
#
# Estado inicial:
# bx -- by
# -- -- --
# px -- py
#
# Passo 1: r1 (1 -> 6)
#   possibilidades: r1, r2, r5, r6, r11, r12, r15, r16
#   recuos neste nó: (nenhuma)
#   aplica r1
# -- -- by
# -- -- bx
# px -- py
#
# Passo 2: r5 (3 -> 4)
#   possibilidades: r5, r6, r11, r15, r16
#   recuos neste nó: (nenhuma)
#   aplica r5
# -- -- --
# by -- bx
# px -- py
#
# Passo 3: r9 (6 -> 1)
#   possibilidades: r9, r11, r15
#   recuos neste nó: (nenhuma)
#   aplica r9
# bx -- --
# by -- --
# px -- py
#
# Passo 4: r2 (1 -> 8)
#   possibilidades: r2, r11, r12, r15
#   recuos neste nó: (nenhuma)
#   aplica r2
# -- -- --
# by -- --
# px bx py
#
# Passo 5: r7 (4 -> 3)
#   possibilidades: r7, r11, r12, r14, r15
#   recuos neste nó: (nenhuma)
#   aplica r7
# -- -- by
# -- -- --
# px bx py
#
# Passo 6: r11 (7 -> 2)
#   possibilidades: r11, r12, r15, r16
#   recuos neste nó: (nenhuma)
#   aplica r11
# -- px by
# -- -- --
# -- bx py
#
# Passo 7: r5 (3 -> 4)
#   possibilidades: r5, r13, r16
#   recuos neste nó: (nenhuma)
#   aplica r5
# -- px --
# by -- --
# -- bx py
#
# Passo 8: r13 (8 -> 1)
#   possibilidades: r13, r14
#   recuos neste nó: (nenhuma)
#   aplica r13
# bx px --
# by -- --
# -- -- py
#
# Passo 9: r1 (1 -> 6)
#   possibilidades: r1, r7
#   recuos neste nó: (nenhuma)
#   aplica r1
# -- px --
# by -- bx
# -- -- py
#
# Passo 10: r7 (4 -> 3)
#   possibilidades: r7, r10
#   recuos neste nó: (nenhuma)
#   aplica r7
# -- px by
# -- -- bx
# -- -- py
#
# Passo 11: r6 (3 -> 8)
#   possibilidades: r6, r9, r10, r16
#   recuos neste nó: (nenhuma)
#   aplica r6
# -- px --
# -- -- bx
# -- by py
#
# Passo 12: r3 (2 -> 7)
#   possibilidades: r3, r9, r10, r13, r16
#   recuos neste nó: (nenhuma)
#   aplica r3
# -- -- --
# -- -- bx
# px by py
#
# Passo 13: r9 (6 -> 1)
#   possibilidades: r9, r13, r15, r16
#   recuos neste nó: (nenhuma)
#   aplica r9
# bx -- --
# -- -- --
# px by py
#
# Passo 14: r11 (7 -> 2)
#   possibilidades: r11, r12, r15, r16
#   recuos neste nó: (nenhuma)
#   aplica r11
# bx px --
# -- -- --
# -- by py
#
# Passo 15: r14 (8 -> 3)
#   possibilidades: r14, r16
#   recuos neste nó: (nenhuma)
#   aplica r14
# bx px by
# -- -- --
# -- -- py
#
# Passo 16: r16 (9 -> 4)
#   possibilidades: r16
#   recuos neste nó: (nenhuma)
#   aplica r16
# bx px by
# py -- --
# -- -- --
#
# Passo 17: r1 (1 -> 6)
#   possibilidades: r1, r2, r3, r4, r6
#   recuos neste nó: (nenhuma)
#   aplica r1
# -- px by
# py -- bx
# -- -- --
#
# Passo 18: r3 (2 -> 7)
#   possibilidades: r3, r4, r6, r10
#   recuos neste nó: (nenhuma)
#   aplica r3
# -- -- by
# py -- bx
# px -- --
#
# Passo 19: r6 (3 -> 8)
#   possibilidades: r6, r9
#   recuos neste nó: (nenhuma)
#   aplica r6
# -- -- --
# py -- bx
# px by --
#
# Passo 20: r7 (4 -> 3)
#   possibilidades: r7, r9, r11, r13
#   recuos neste nó: (nenhuma)
#   aplica r7
# -- -- py
# -- -- bx
# px by --
#
# Passo 21: r9 (6 -> 1)
#   possibilidades: r9, r11, r13
#   recuos neste nó: (nenhuma)
#   aplica r9
# bx -- py
# -- -- --
# px by --
#
# Passo 22: r5 (3 -> 4)
#   possibilidades: r5, r11, r12
#   recuos neste nó: (nenhuma)
#   aplica r5
# bx -- --
# py -- --
# px by --
#
# Passo 23: r11 (7 -> 2)
#   possibilidades: r11, r12, r14
#   recuos neste nó: (nenhuma)
#   aplica r11
# bx px --
# py -- --
# -- by --
#
# Passo 24: r1 (1 -> 6)
#   possibilidades: r1, r4, r7
#   recuos neste nó: (nenhuma)
#   aplica r1
# -- px --
# py -- bx
# -- by --
#
# Passo 25: r4 (2 -> 9)
#   possibilidades: r4, r7, r10, r13
#   recuos neste nó: (nenhuma)
#   aplica r4
# -- -- --
# py -- bx
# -- by px
#
# Passo 26: r7 (4 -> 3)
#   possibilidades: r7, r9, r10, r13, r14
#   recuos neste nó: (nenhuma)
#   aplica r7
# -- -- py
# -- -- bx
# -- by px
#
# Passo 27: r10 (6 -> 7)
#   possibilidades: r9, r10, r13, r15, r16
#   recuos neste nó: r9
#   aplica r10
# -- -- py
# -- -- --
# bx by px
#
# Passo 28: r11 (7 -> 2)
#   possibilidades: r5, r11, r13, r15, r16
#   recuos neste nó: r5
#   aplica r11
# -- bx py
# -- -- --
# -- by px
#
# Passo 29: r13 (8 -> 1)
#   possibilidades: r5, r13, r16
#   recuos neste nó: r5
#   aplica r13
# by bx py
# -- -- --
# -- -- px
#
# Passo 30: r1 (1 -> 6)
#   possibilidades: r1, r3, r5, r6, r16
#   recuos neste nó: (nenhuma)
#   aplica r1
# -- bx py
# -- -- by
# -- -- px
#
# Passo 31: r6 (3 -> 8)
#   possibilidades: r3, r5, r6, r10, r16
#   recuos neste nó: r3, r5
#   aplica r6
# -- bx --
# -- -- by
# -- py px
#
# Passo 32: r10 (6 -> 7)
#   possibilidades: r3, r9, r10, r13, r16
#   recuos neste nó: r3, r9
#   aplica r10
# -- bx --
# -- -- --
# by py px
#
# Passo 33: r13 (8 -> 1)
#   possibilidades: r13, r14, r16
#   recuos neste nó: (nenhuma)
#   aplica r13
# py bx --
# -- -- --
# by -- px
#
# Passo 34: r16 (9 -> 4)
#   possibilidades: r1, r12, r16
#   recuos neste nó: r1, r12
#   aplica r16
# py bx --
# px -- --
# by -- --
#
# Passo 35: r4 (2 -> 9)
#   possibilidades: r1, r2, r4, r7, r12
#   recuos neste nó: r1, r2
#   aplica r4
# py -- --
# px -- --
# by -- bx
#
# Passo 36: r7 (4 -> 3)
#   possibilidades: r1, r2, r7, r11, r12
#   recuos neste nó: r1, r2
#   aplica r7
# py -- px
# -- -- --
# by -- bx
